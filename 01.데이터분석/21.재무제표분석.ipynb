# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('2021_1분기보고서_01_재무상태표_20220215.txt', sep='\t', encoding='euc-kr')
df1.head(3)
# Out:
#                   재무제표종류      종목코드 회사명       시장구분   업종       업종명  결산월  \
# 0  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업    3
# 1  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업    3
# 2  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  262  전자부품 제조업    3
#
#         결산기준일   보고서종류   통화                              항목코드             항목명  \
# 0  2021-06-30  1분기보고서  KRW          ifrs-full_AssetsAbstract   자산 [abstract]
# 1  2021-06-30  1분기보고서  KRW           ifrs-full_CurrentAssets            유동자산
# 2  2021-06-30  1분기보고서  KRW  ifrs-full_CashAndCashEquivalents        현금및현금성자산
#
#           당기 1분기말             전기말  전전기말  Unnamed: 15
# 0             NaN             NaN   NaN          NaN
# 1  17,360,014,259  16,020,752,276   NaN          NaN
# 2   5,077,783,055   5,202,901,349   NaN          NaN

# %%
df = df1[['종목코드','업종명','항목명', '당기 1분기말']]
df.head(5)
# Out:
#        종목코드       업종명              항목명         당기 1분기말
# 0  [060310]  전자부품 제조업    자산 [abstract]             NaN
# 1  [060310]  전자부품 제조업             유동자산  17,360,014,259
# 2  [060310]  전자부품 제조업         현금및현금성자산   5,077,783,055
# 3  [060310]  전자부품 제조업        매출채권및기타채권   5,610,552,264
# 4  [060310]  전자부품 제조업             재고자산   3,672,398,945

# %%
df.groupby('종목코드')[['업종명','항목명', '당기 1분기말']]
df.head()
# Out:
#        종목코드       업종명              항목명         당기 1분기말
# 0  [060310]  전자부품 제조업    자산 [abstract]             NaN
# 1  [060310]  전자부품 제조업             유동자산  17,360,014,259
# 2  [060310]  전자부품 제조업         현금및현금성자산   5,077,783,055
# 3  [060310]  전자부품 제조업        매출채권및기타채권   5,610,552,264
# 4  [060310]  전자부품 제조업             재고자산   3,672,398,945
