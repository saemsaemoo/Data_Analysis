# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # ㅈㅓㅇ리

# %%
df2017_1 = pd.read_excel('/Users/kimhansaem/workspace/11.DataAnalysis/01.데이터분석/data/재무제표파일/2017_1분기.xlsx')
df2017_1.head(3)
# Out:
#    Unnamed: 0  corp_code corp_name  stock_code           당기순이익  \
# 0           0     365387    AJ네트웍스       95570   6,878,386,773
# 1           1     125080     AK홀딩스        6840  43,407,295,013
# 2           2     219097       BGF       27410  32,090,130,727
#
#                  매출액               부채총계            영업이익               유동부채  \
# 0    351,523,189,411  1,695,393,307,678  21,827,395,587    996,373,681,686
# 1    820,740,707,452  1,751,152,521,875  66,723,415,561  1,341,067,784,082
# 2  1,215,645,931,124  1,022,440,656,635  39,634,034,678    771,067,992,964
#
#                 유동자산            이익잉여금             자본금               자본총계  \
# 0    309,634,160,616                0  46,822,295,000    429,074,162,552
# 1  1,156,717,911,454                0               0  1,024,648,091,822
# 2    986,585,650,559  794,887,828,227               0    933,367,940,292
#
#                 자산총계
# 0  2,124,467,470,230
# 1  2,775,800,613,697
# 2  1,955,808,596,927

# %%
df2017_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  413 non-null    int64
#  1   corp_code   413 non-null    int64
#  2   corp_name   413 non-null    object
#  3   stock_code  413 non-null    int64
#  4   당기순이익       413 non-null    object
#  5   매출액         413 non-null    object
#  6   부채총계        413 non-null    object
#  7   영업이익        413 non-null    object
#  8   유동부채        413 non-null    object
#  9   유동자산        413 non-null    object
#  10  이익잉여금       413 non-null    object
#  11  자본금         413 non-null    object
#  12  자본총계        413 non-null    object
#  13  자산총계        413 non-null    object
# dtypes: int64(3), object(11)
# memory usage: 45.3+ KB

# %%
df2017_1 =df2017_1.drop(['Unnamed: 0','유동부채','유동자산', '자본금','자본총계','자산총계','stock_code'], axis=1)
df2017_1.head(3)
# Out:
#    corp_code corp_name           당기순이익                매출액               부채총계  \
# 0     365387    AJ네트웍스   6,878,386,773    351,523,189,411  1,695,393,307,678
# 1     125080     AK홀딩스  43,407,295,013    820,740,707,452  1,751,152,521,875
# 2     219097       BGF  32,090,130,727  1,215,645,931,124  1,022,440,656,635
#
#              영업이익            이익잉여금
# 0  21,827,395,587                0
# 1  66,723,415,561                0
# 2  39,634,034,678  794,887,828,227

# %%
df2017_1 = df2017_1.rename({'당기순이익':'2017_1당기순이익', '매출액':'2017_1매출액', '부채총계':'2017_1부채', '영업이익':'2017_1영업이익', '이익잉여금':'2017_1이익잉여금'}, axis='columns')
df2017_1
# Out:
#      corp_code corp_name      2017_1당기순이익          2017_1매출액  \
# 0       365387    AJ네트웍스    6,878,386,773    351,523,189,411
# 1       125080     AK홀딩스   43,407,295,013    820,740,707,452
# 2       219097       BGF   32,090,130,727  1,215,645,931,124
# 3       122579       BYC    2,704,119,808     46,036,699,089
# 4       148540        CJ  172,751,656,000  6,349,714,131,000
# ..         ...       ...              ...                ...
# 408     595191        후성   12,852,362,208     59,465,885,373
# 409     195229     휠라홀딩스   25,539,119,982    653,700,824,429
# 410     362238       휴비스                -                  -
# 411     426086       휴켐스   29,285,709,216    187,780,593,384
# 412     167208      흥아해운  -30,344,416,196    196,209,288,785
#
#                2017_1부채       2017_1영업이익        2017_1이익잉여금
# 0     1,695,393,307,678   21,827,395,587                  0
# 1     1,751,152,521,875   66,723,415,561                  0
# ...

# %%
df2017_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   corp_code    413 non-null    int64
#  1   corp_name    413 non-null    object
#  2   2017_1당기순이익  413 non-null    object
#  3   2017_1매출액    413 non-null    object
#  4   2017_1부채     413 non-null    object
#  5   2017_1영업이익   413 non-null    object
#  6   2017_1이익잉여금  413 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 22.7+ KB

# %%
df2017_1.isnull().sum()
# Out:
# corp_code      0
# corp_name      0
# 2017_1당기순이익    0
# 2017_1매출액      0
# 2017_1부채       0
# 2017_1영업이익     0
# 2017_1이익잉여금    0
# dtype: int64

# %%
df2017_2 =df2017_2.drop(['Unnamed: 0','유동부채','유동자산', '자본금','자본총계','자산총계','stock_code'], axis=1)
df2017_2.head(3)
# Out:
#    corp_code corp_name           당기순이익                매출액               부채총계  \
# 0     365387    AJ네트웍스   5,111,392,411    337,764,161,348  1,757,596,715,794
# 1     125080     AK홀딩스  38,874,109,446    795,495,426,569  1,710,653,032,430
# 2     219097       BGF  61,212,937,931  1,412,995,579,893  1,094,076,126,281
#
#              영업이익            이익잉여금
# 0  19,962,227,088                0
# 1  54,142,066,193                0
# 2  74,110,709,511  855,742,914,552

# %%
df2017_2 = df2017_2.rename({'당기순이익':'2017_2당기순이익', '매출액':'2017_2매출액', '부채총계':'2017_2부채', '영업이익':'2017_2영업이익', '이익잉여금':'2017_2이익잉여금'}, axis='columns')
df2017_2
# Out:
#      corp_code corp_name      2017_2당기순이익          2017_2매출액  \
# 0       365387    AJ네트웍스    5,111,392,411    337,764,161,348
# 1       125080     AK홀딩스   38,874,109,446    795,495,426,569
# 2       219097       BGF   61,212,937,931  1,412,995,579,893
# 3       122579       BYC    2,474,804,499     45,160,283,840
# 4       148540        CJ  502,249,281,000  6,504,953,550,000
# ..         ...       ...              ...                ...
# 417     595191        후성    3,222,739,131     65,745,832,148
# 418     195229     휠라홀딩스   46,759,694,717    692,867,158,635
# 419     362238       휴비스    4,796,593,672    295,979,799,314
# 420     426086       휴켐스   37,186,334,935    185,130,578,820
# 421     167208      흥아해운     -593,051,377    211,346,804,995
#
#                2017_2부채       2017_2영업이익        2017_2이익잉여금
# 0     1,757,596,715,794   19,962,227,088                  0
# 1     1,710,653,032,430   54,142,066,193                  0
# ...

# %%
df1 = df2017_1.copy()
df2 = df2017_2.copy()

# %%
df['영업이익률'] = df['영업이익'] / df['매출액'] * 100
df['순이익률'] = df['당기순이익'] / df['매출액'] * 100
df['ROE'] = df['당기순이익'] / df['자본총계'] * 100
df['부채비율'] = df['부채총계'] / df['자산총계'] * 100
df['당좌비율'] = df['유동자산'] / df['유동부채'] * 100
df['유보율'] = df['이익잉여금'] / df['자본금'] * 100

# %%
df_merge = pd.merge(df1,df2, how='right')
df_merge
# Out:
#      corp_code corp_name      2017_1당기순이익          2017_1매출액  \
# 0       365387    AJ네트웍스    6,878,386,773    351,523,189,411
# 1       125080     AK홀딩스   43,407,295,013    820,740,707,452
# 2       219097       BGF   32,090,130,727  1,215,645,931,124
# 3       122579       BYC    2,704,119,808     46,036,699,089
# 4       148540        CJ  172,751,656,000  6,349,714,131,000
# ..         ...       ...              ...                ...
# 417     595191        후성   12,852,362,208     59,465,885,373
# 418     195229     휠라홀딩스   25,539,119,982    653,700,824,429
# 419     362238       휴비스                -                  -
# 420     426086       휴켐스   29,285,709,216    187,780,593,384
# 421     167208      흥아해운  -30,344,416,196    196,209,288,785
#
#                2017_1부채       2017_1영업이익        2017_1이익잉여금      2017_2당기순이익  \
# 0     1,695,393,307,678   21,827,395,587                  0    5,111,392,411
# ...

# %%
df_merge.isnull().sum()
# Out:
# corp_code      0
# corp_name      0
# 2017_1당기순이익    9
# 2017_1매출액      9
# 2017_1부채       9
# 2017_1영업이익     9
# 2017_1이익잉여금    9
# 2017_2당기순이익    0
# 2017_2매출액      0
# 2017_2부채       0
# 2017_2영업이익     0
# 2017_2이익잉여금    0
# dtype: int64

# %%
df_merge = df_merge[df_merge['2017_1당기순이익'].notnull()]
df_merge.isnull().sum()
# Out:
# corp_code      0
# corp_name      0
# 2017_1당기순이익    0
# 2017_1매출액      0
# 2017_1부채       0
# 2017_1영업이익     0
# 2017_1이익잉여금    0
# 2017_2당기순이익    0
# 2017_2매출액      0
# 2017_2부채       0
# 2017_2영업이익     0
# 2017_2이익잉여금    0
# dtype: int64

# %%
df_merge['2017_1부채'] = df_merge['2017_1부채'].apply(lambda x: int(x.replace(',','')))

# %%
df_merge['2017_2부채'] = df_merge['2017_2부채'].apply(lambda x: int(x.replace(',','')))

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413 entries, 0 to 421
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   corp_code    413 non-null    int64
#  1   corp_name    413 non-null    object
#  2   2017_1당기순이익  413 non-null    object
#  3   2017_1매출액    413 non-null    object
#  4   2017_1부채     413 non-null    int64
#  5   2017_1영업이익   413 non-null    object
#  6   2017_1이익잉여금  413 non-null    object
#  7   2017_2당기순이익  413 non-null    object
#  8   2017_2매출액    413 non-null    object
#  9   2017_2부채     413 non-null    int64
#  10  2017_2영업이익   413 non-null    object
#  11  2017_2이익잉여금  413 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 41.9+ KB

# %%
df_merge['2017_1매출액'] = df_merge['2017_1매출액'].replace('-','')

# %%
df_merge['2017_1매출액'] = df_merge['2017_1매출액'].replace('-','')
# Out:
#      corp_code corp_name      2017_1당기순이익          2017_1매출액        2017_1부채  \
# 0       365387    AJ네트웍스    6,878,386,773    351,523,189,411   1695393307678
# 1       125080     AK홀딩스   43,407,295,013    820,740,707,452   1751152521875
# 2       219097       BGF   32,090,130,727  1,215,645,931,124   1022440656635
# 3       122579       BYC    2,704,119,808     46,036,699,089    335000271712
# 4       148540        CJ  172,751,656,000  6,349,714,131,000  15420143327000
# ..         ...       ...              ...                ...             ...
# 417     595191        후성   12,852,362,208     59,465,885,373    129318023320
# 418     195229     휠라홀딩스   25,539,119,982    653,700,824,429   2041501488623
# 419     362238       휴비스                -                       536575958352
# 420     426086       휴켐스   29,285,709,216    187,780,593,384    281175238501
# 421     167208      흥아해운  -30,344,416,196    196,209,288,785    738871088494
#
# ...

# %%
df_merge['2017_1당기순이익'] = df_merge['2017_1당기순이익'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_1매출액'] = df_merge['2017_1매출액'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_1부채'] = df_merge['2017_1부채'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_1영업이익'] = df_merge['2017_1영업이익'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_1이익잉여금'] = df_merge['2017_1이익잉여금'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_2당기순이익'] = df_merge['2017_2당기순이익'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_2매출액'] = df_merge['2017_2매출액'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_2부채'] = df_merge['2017_2부채'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_2영업이익'] = df_merge['2017_2영업이익'].apply(lambda x: int(x.replace(',','')))
df_merge['2017_2이익잉여금'] = df_merge['2017_2이익잉여금'].apply(lambda x: int(x.replace(',','')))

df_merge.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l6/zf_y8js55058y519pbd3k9480000gn/T/ipykernel_35464/1197599667.py in <module>
# ----> 1 df_merge['2017_1당기순이익'] = df_merge['2017_1당기순이익'].apply(lambda x: int(x.replace(',','')))
#       2 df_merge['2017_1매출액'] = df_merge['2017_1매출액'].apply(lambda x: int(x.replace(',','')))
#       3 df_merge['2017_1부채'] = df_merge['2017_1부채'].apply(lambda x: int(x.replace(',','')))
#       4 df_merge['2017_1영업이익'] = df_merge['2017_1영업이익'].apply(lambda x: int(x.replace(',','')))
#       5 df_merge['2017_1이익잉여금'] = df_merge['2017_1이익잉여금'].apply(lambda x: int(x.replace(',','')))
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# ...
