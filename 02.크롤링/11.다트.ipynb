# %%
# !pip install dart-fss
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 KB 2.6 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 33.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3377 lines of output]
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.8" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
# ...
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.6 MB/s eta 0:00:00
# ...
#         Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# ...

# %%
import dart-fss as dart
# Out:
#   File "/var/folders/l6/zf_y8js55058y519pbd3k9480000gn/T/ipykernel_86384/4269296231.py", line 1
#     import dart-fss as dart
#                ^
# SyntaxError: invalid syntax

# %%
# !pip install dart-fss
# Out:
# ...
#   Using cached dart_fss-0.3.16-py3-none-any.whl (125 kB)
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 KB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached pandas-1.2.5.tar.gz (5.5 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3373 lines of output]
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.8" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
# ...
#         Using cached setuptools-60.9.3-py3-none-any.whl (1.1 MB)
# ...

# %%
import dart-fss as dart
